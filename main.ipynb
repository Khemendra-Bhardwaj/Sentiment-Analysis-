# %%
import numpy as np
import pandas as pd
import re

# %%
data= pd.read_csv("youtube_dataset.csv")

data.head(10)
# Out:
#                                              Comment                  Date  \
# 0  The people who liked this comment is officiall...  2020-08-10T20:00:43Z
# 1           - Wait, it's 7B views\n- Always has been  2020-09-07T20:52:36Z
# 2  *Teacher: What is the population of the Earth?...  2019-11-21T03:23:32Z
# 3  Let's be honest this wasn't your recommendatio...  2020-09-09T03:41:34Z
# 4  Types Of People:\n10% Enjoying Song \n90% Chec...  2020-09-08T09:53:24Z
# 5  3.2 Million comments if you find mine your a l...  2020-03-15T21:11:08Z
# 6  claim your “here before 7 billion” tickets her...  2020-09-08T06:01:36Z
# 7  The ones who are NOT from Tik-Tok can like thi...  2020-09-08T08:44:47Z
# 8   Song: spanish\nComments: English\nHotel: trivago  2020-09-09T01:17:50Z
# 9                                    Kimler burda😂🥰🌹  2020-09-08T07:28:39Z
#
#     Likes
# 0   98280
# 1     773
# 2  356081
# 3      13
# 4     122
# 5  370547
# 6     763
# 7      94
# 8     150
# 9      45

# %%
data.shape
# Out:
# (19300, 3)

# %%
data.isnull().sum()
# Out:
# Comment    0
# Date       0
# Likes      0
# dtype: int64

# %%
data["Comment"] = data["Comment"].str.replace("[^a-zA-Z#]", " ")
data["Comment"] = data["Comment"].apply(lambda x: ' '.join([w for w in x.split() if len(w)>2]))
data["Comment"] = data["Comment"].apply(lambda x:x.lower())
# Out:
# <ipython-input-5-969631473386>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Comment"] = data["Comment"].str.replace("[^a-zA-Z#]", " ")

# %%
data.head(10)
# Out:
#                                              Comment                  Date  \
# 0  the people who liked this comment officially b...  2020-08-10T20:00:43Z
# 1                         wait views always has been  2020-09-07T20:52:36Z
# 2  teacher what the population the earth around o...  2019-11-21T03:23:32Z
# 3  let honest this wasn your recommendation you s...  2020-09-09T03:41:34Z
# 4          types people enjoying song checking views  2020-09-08T09:53:24Z
# 5         million comments you find mine your legend  2020-03-15T21:11:08Z
# 6  claim your here before billion tickets here th...  2020-09-08T06:01:36Z
# 7  the ones who are not from tik tok can like thi...  2020-09-08T08:44:47Z
# 8        song spanish comments english hotel trivago  2020-09-09T01:17:50Z
# 9                                       kimler burda  2020-09-08T07:28:39Z
#
#     Likes
# 0   98280
# 1     773
# 2  356081
# 3      13
# 4     122
# 5  370547
# 6     763
# 7      94
# 8     150
# 9      45

# %%
data2=data.sample(10000)
data2.shape
# Out:
# (10000, 3)

# %%
import nltk

# %%
data2['Comment'] = data['Comment'].apply(lambda x: x.split())
data2.head()
# Out:
#                                                  Comment  \
# 3199   [fun, fact, this, wasn, recommended, you, you,...
# 17119         [popular, opinion, this, song, still, bop]
# 16325  [wow, she, naked, lord, don, lick, that, coron...
# 8052   [mandel, dos, bailes, sica, muito, foda, galer...
# 4185   [exitaso, para, empezar, like, paras, escuchar...
#
#                        Date  Likes
# 3199   2020-05-20T17:09:05Z  12023
# 17119  2020-09-07T22:41:21Z      2
# 16325  2020-08-03T07:42:55Z   6064
# 8052   2020-09-08T15:37:46Z      1
# 4185   2019-01-08T16:58:26Z    254

# %%
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

wnl = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
data2['Comment'].apply(lambda x: [wnl.lemmatize(i) for i in x if i not in set(stopwords.words('english'))])
data2.head()
# Out:
#                                                  Comment  \
# 3199   [fun, fact, this, wasn, recommended, you, you,...
# 17119         [popular, opinion, this, song, still, bop]
# 16325  [wow, she, naked, lord, don, lick, that, coron...
# 8052   [mandel, dos, bailes, sica, muito, foda, galer...
# 4185   [exitaso, para, empezar, like, paras, escuchar...
#
#                        Date  Likes
# 3199   2020-05-20T17:09:05Z  12023
# 17119  2020-09-07T22:41:21Z      2
# 16325  2020-08-03T07:42:55Z   6064
# 8052   2020-09-08T15:37:46Z      1
# 4185   2019-01-08T16:58:26Z    254

# %%
def join_back(list_input):
  return " ".join(list_input)

data2['Comment'] =data2['Comment'].apply(join_back)
data2.shape
data2.head(10)
# Out:
#                                                  Comment  \
# 3199   fun fact this wasn recommended you you searche...
# 17119                popular opinion this song still bop
# 16325       wow she naked lord don lick that coronavirus
# 8052   mandel dos bailes sica muito foda galera acess...
# 4185   exitaso para empezar like paras escuchar este ...
# 18517  han pasado tres desde que sali este tema todav...
# 4148   insert brian dozier and the nats singing the l...
# 11198  want ddu ddu surpass her two sunbaenim gangnam...
# 4991                 cuenta canci favorita becky mayores
# 5831         jesus christ the dancing just good the song
#
#                        Date  Likes
# 3199   2020-05-20T17:09:05Z  12023
# 17119  2020-09-07T22:41:21Z      2
# 16325  2020-08-03T07:42:55Z   6064
# 8052   2020-09-08T15:37:46Z      1
# 4185   2019-01-08T16:58:26Z    254
# 18517  2020-07-24T04:42:31Z    233
# 4148   2020-09-04T04:58:58Z      9
# 11198  2019-11-21T15:42:57Z    140
# ...

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
data2['Sentiment Scores'] = data2['Comment'].apply(lambda x:sia.polarity_scores(x)['compound'])

# %%
data2['Sentiment'] = data2['Sentiment Scores'].apply(lambda s : 'Positive' if s > 0 else ('Neutral' if s == 0 else 'Negative'))
data2.head(10)
# Out:
#                                                  Comment  \
# 3199   fun fact this wasn recommended you you searche...
# 17119                popular opinion this song still bop
# 16325       wow she naked lord don lick that coronavirus
# 8052   mandel dos bailes sica muito foda galera acess...
# 4185   exitaso para empezar like paras escuchar este ...
# 18517  han pasado tres desde que sali este tema todav...
# 4148   insert brian dozier and the nats singing the l...
# 11198  want ddu ddu surpass her two sunbaenim gangnam...
# 4991                 cuenta canci favorita becky mayores
# 5831         jesus christ the dancing just good the song
#
#                        Date  Likes  Sentiment Scores Sentiment
# 3199   2020-05-20T17:09:05Z  12023            0.6249  Positive
# 17119  2020-09-07T22:41:21Z      2            0.4215  Positive
# 16325  2020-08-03T07:42:55Z   6064            0.5859  Positive
# 8052   2020-09-08T15:37:46Z      1            0.3612  Positive
# ...

# %%
data2.drop(['Sentiment Scores'], axis=1,inplace=True)
data2.drop(['Date','Likes'],axis=1,inplace=True)
data2.head(5)
# Out:
#                                                  Comment Sentiment
# 3199   fun fact this wasn recommended you you searche...  Positive
# 17119                popular opinion this song still bop  Positive
# 16325       wow she naked lord don lick that coronavirus  Positive
# 8052   mandel dos bailes sica muito foda galera acess...  Positive
# 4185   exitaso para empezar like paras escuchar este ...  Positive

# %% [markdown]
# Dataframe is now ready

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=10000)

# %%
X= cv.fit_transform(data2['Comment']).toarray()

# %%
X.shape
# Out:
# (10000, 10000)

# %%
data2['Sentiment'].replace({'Positive':1,'Negative':0,'Neutral':2},inplace=True)
data2.head(3)
# Out:
#                                                  Comment  Sentiment
# 3199   fun fact this wasn recommended you you searche...          1
# 17119                popular opinion this song still bop          1
# 16325       wow she naked lord don lick that coronavirus          1

# %%
Y=data2.iloc[:,-1].values

# %%
Y.shape
# Out:
# (10000,)

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.2)

# %%
x_train.shape
# Out:
# (8000, 10000)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB

nb1=GaussianNB()
nb2=MultinomialNB()
nb3=BernoulliNB()

# %%
nb1.fit(x_train,y_train)
nb2.fit(x_train,y_train)
nb3.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
y_pred1=nb1.predict(x_test)
y_pred2=nb2.predict(x_test)
y_pred3=nb3.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Gaussian/Normal distribution Naive Bayes accuracy",accuracy_score(y_test,y_pred1))

print("Multinomial distribution Naive Bayes accuracy",accuracy_score(y_test,y_pred2))

print("Bernouli distribution Naive Bayes accuracy",accuracy_score(y_test,y_pred3))
# Out:
# Gaussian/Normal distribution Naive Bayes accuracy 0.5105
# Multinomial distribution Naive Bayes accuracy 0.754
# Bernouli distribution Naive Bayes accuracy 0.7355
